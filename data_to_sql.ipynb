# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy import create_engine, text

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\shank\Desktop\github_data\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#creating sql engine
engine = create_engine('mysql+mysqlconnector://root:Shankii007@localhost:3306/github')

# %%
#pushing dataframe to sql
df.to_sql('Iris_data', con=engine, if_exists='replace', index=False)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_2420\3045256054.py:2: UserWarning: The provided table name 'Iris_data' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Iris_data', con=engine, if_exists='replace', index=False)
# 150

# %%
# Verify data insertion
with engine.connect() as conn:
    query = text('SELECT * FROM Iris_data')
    result = conn.execute(query)
    for row in result:
        print(row)

print("sucessfully inserted")
# Out:
# (1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa')
# (2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa')
# (3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa')
# (4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa')
# (5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa')
# (6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa')
# (7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa')
# (8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa')
# (9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa')
# (10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa')
# (11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa')
# (12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa')
# (13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa')
# (14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa')
# (15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa')
# (16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa')
# (17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa')
# (18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa')
# (19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa')
# (20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa')
# (21, 5.4, 3.4, 1.7, 0.2, 'Iris-setosa')
# (22, 5.1, 3.7, 1.5, 0.4, 'Iris-setosa')
# (23, 4.6, 3.6, 1.0, 0.2, 'Iris-setosa')
# (24, 5.1, 3.3, 1.7, 0.5, 'Iris-setosa')
# ...
